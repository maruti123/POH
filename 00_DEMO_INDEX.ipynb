# %% [markdown]
# # Partner Demos: February 2026 Features
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/maruti123/POH/blob/main/00_DEMO_INDEX.ipynb)
#
# Welcome to the demo collection for the latest Google Cloud Data & AI features released in February 2026. This collection is designed for partners to showcase simple, actionable use cases to their clients.
#
# ## BigQuery Demos
# - [BigQuery Global Queries](./bq_global_queries_demo.ipynb): Join datasets across multiple regions.
# - [BigQuery Dataset Insights](./bq_dataset_insights_demo.ipynb): Automated relationship graphs and dataset summaries.
# - [Conversational Glossary](./bq_conversational_glossary_demo.ipynb): Define business logic for AI interpretation.
#
# ## AI & Agentic Development Demos
# - [Managed MCP: Firestore](./mcp_firestore_demo.ipynb): Using Firestore as a tool via MCP.
# - [Gemini 3.1 Flash Image](./gemini_3_1_flash_image_demo.ipynb): High-quality, low-latency image generation.
# - [Gemini CLI Browser Agent](./gemini_cli_browser_agent.md): (Markdown Walkthrough) Web interaction from the terminal.
#
# ## Infrastructure & Governance Demos
# - [Dataplex Metadata Change Feeds](./dataplex_change_feed_demo.ipynb): Real-time governance via Pub/Sub notifications.
